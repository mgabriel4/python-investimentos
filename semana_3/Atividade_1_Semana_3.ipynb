# %% [markdown]
# # Coleções e Matrizes

# %% [markdown]
# ## Exercício 1 - listas
#
# Crie uma estrutura de repetição para fazer a leitura de 5 números inteiros e os armazene dentro de uma lista. Após a leitura, crie outra estrutura de repetição para somar todos os valores digitados

# %%
numeros = []

for i in range(5):
    numero = int(input("Insira um número na lista: "))
    numeros.append(numero)

print("Os números inseridos são:", numeros)
# Out:
# Os números inseridos são: [5, 4, 9, 3, 66]

# %%
for numero in numeros:
    soma = sum(numeros)

print("A soma dos números inseridos é:", soma)
# Out:
# A soma dos números inseridos é: 87

# %% [markdown]
# ## Exercícios 2 - dicionários
#
# Crie um dicionário para armazenar o nome e a nota de 3 alunos, fazendo a leitura dos valores por meio de uma estrutura de repetição. Depois, crie uma nova estrutura de repetição para somar todas as notas e retornar a média

# %%
alunos = {}

for i in range(3):
    nome = input("Insira o nome do aluno: ")
    nota = float(input("Insira a nota do aluno: "))
    alunos[nome] = nota

print("Os alunos e suas notas são:")
for nome, nota in alunos.items():
    print(f"{nome}: {nota}")
# Out:
# Os alunos e suas notas são:
# joão: 5.0
# maria: 7.0
# lais: 9.0

# %%
for nota in alunos.values():
    soma = sum(alunos.values())
    media = soma / len(alunos)

print("A soma das notas dos alunos é:", soma)
print("A média das notas dos alunos é:", media)
# Out:
# A soma das notas dos alunos é: 21.0
# A média das notas dos alunos é: 7.0

# %% [markdown]
# ## Exercício 3: Matriz
#
# Dada a matriz abaixo, construa uma estrutura de repetição para percorrer e somar todos os elementos da matriz

# %%
# %pip install numpy
import numpy as np
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-2.5.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Downloading numpy-2.5.2-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 6.7 MB/s  0:00:02 eta 0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
matriz = np.array([[3, 4, 1],
                   [3, 1, 5]])
matriz
# Out:
# array([[3, 4, 1],
#        [3, 1, 5]])

# %%
soma = 0
for linha in matriz:
    for numero in linha:
        soma += numero

print("A soma dos elementos da matriz é:", soma)
# Out:
# A soma dos elementos da matriz é: 17
